# %% [markdown]
# ### Preliminary cell to start the notebook

# %%
# libraries
import os
import sys
import platform
print(sys.version)

in_colab = 'google.colab' in sys.modules
strong_pc = platform.system() == 'Linux'

if in_colab:
    if not os.getcwd().split('/')[-1].split('_')[-1]=='2023':
        from google.colab import drive
        drive.mount('/content/drive')
        os.chdir(r'/content/drive/MyDrive/Human_Data_Analytics_Project_2023')

    if not 'tensorflow_io' in sys.modules:
        print('Installing tensorflow-IO')
        # !pip install tensorflow-io
    if not 'keras' in sys.modules:
        print('Installing keras')
        # !pip install keras==2.10.0
    if not 'scikeras' in sys.modules:
        print('Installing scikeras')
        # !pip install scikeras[tensorflow]
    if not 'keras-tuner' in sys.modules:
        print('installing keras tuner')
        # !pip install keras-tuner
        # !pip install numba==0.57.0

main_dir = os.getcwd()
if main_dir not in sys.path:
    print('Adding the folder for the modules')
    sys.path.append(main_dir)

#BASE LIBRARIES
import numpy as np
import pandas as pd
import h5py
import shutil
import time
import random
import subprocess
import itertools
import warnings
import pickle
import json

#PLOT LIBRARIES
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
#import plotly.express as px

#AUDIO LIBRARIES
import librosa
from scipy.io import wavfile
from scipy import signal
from scipy.fft import fft,ifft,fftfreq, fftshift
from scipy.signal import stft,spectrogram,periodogram
#from pydub import AudioSegment

#MACHINE LEARNING LIBRARIES
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, LeaveOneOut, train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.utils import check_random_state
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model as tf_plot
if in_colab:
    import tensorflow_io as tfio
print("TensorFlow version:", tf.__version__)
# show keras version
import keras
print(f'keras version = {keras.__version__}')
#import keras_tune as kt
from keras import layers
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras.regularizers import L1L2
# kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4) # we may use this in some layers...

#RANDOM SETTINGS
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
check_random_state(seed)

#EVALUATION LIBRAIRES
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_curve
from sklearn.metrics import make_scorer
from sklearn.metrics import RocCurveDisplay, precision_recall_curve, PrecisionRecallDisplay
from sklearn.metrics import precision_recall_fscore_support, auc

#OUR PERSONAL FUNCTIONS
import importlib
from Preprocessing.data_loader import download_dataset,load_metadata
from Preprocessing.exploration_plots import one_random_audio, plot_clip_overview, Spectral_Analysis
from Models.basic_ml import basic_ML_experiments, basic_ML_experiments_gridsearch, build_dataset, extract_flatten_MFCC
from Visualization.model_plot import confusion_matrix,listen_to_wrong_audio

importlib.reload(importlib.import_module('Preprocessing.data_loader'))
importlib.reload(importlib.import_module('Models.basic_ml'))
importlib.reload(importlib.import_module('Visualization.model_plot'))

from Preprocessing.data_loader import load_metadata
#df_ESC10, df_ESC50 = load_metadata(main_dir,heads = False, ESC_US = False, statistics=False)

from Preprocessing.data_loader import load_metadata
from Models.basic_ml import basic_ML_experiments, basic_ML_experiments_gridsearch, build_dataset, extract_flatten_MFCC

importlib.reload(importlib.import_module('Models.ann_utils'))
importlib.reload(importlib.import_module('Visualization.model_plot'))

from Models.ann_utils import *
from Models.ann_utils import MFCCWithDeltaLayer,OutputCutterLayer
from Visualization.model_plot import plot_history, confusion_matrix, listen_to_wrong_audio, visualize_the_weights

ESC10_path = os.path.join(main_dir,'Data', 'ESC-10-depth')
samplerate = 44100
# Out:
# 3.11.4 (main, Jul  5 2023, 08:54:11) [Clang 14.0.6 ]
# /Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ["[Errno 2] The file to load file system plugin from does not exist.: '/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/libtensorflow_io_plugins.so'"]
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ["dlopen(/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/libtensorflow_io.so, 0x0006): tried: '/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow_io-0.33.0-py3.11-macosx-11.1-arm64.egg/tensorflow_io/python/ops/libtensorflow_io.so' (no such file)"]
#   warnings.warn(f"file system plugins are not loaded: {e}")
# TensorFlow version: 2.12.0
# keras version = 2.12.0

# %% [markdown]
# # 3 UNSUPERVISED LEARNING: AUTOENCODERS

# %%
import importlib
importlib.reload(importlib.import_module('Models.ann_utils'))
importlib.reload(importlib.import_module('Visualization.model_plot'))
importlib.reload(importlib.import_module('Preprocessing.data_loader'))
from Models.ann_utils import *
from Preprocessing.data_loader import reshape_US
from Visualization.model_plot import *

# %% [markdown]
# ## 3.6 Autoencoder on preprocessed audio STFT - Fully Convolutional AE

# %% [markdown]
# Again, we'll train the autoencoder only to reconstruct MFCC or STFT audio, not the one preprocessed by MEL.

# %% [markdown]
# ### Create the dataset

# %% [markdown]
# The dataset is not changed from before.

# %%
strong_pc = True
preprocessing = 'STFT'
AE_name = 'Fully_Convolutional_AE_'+preprocessing
train, val, test, INPUT_DIM =  create_US_dataset(folder_number=1, preprocessing = 'STFT', main_dir = main_dir)
# Out:
# Creating the dataset from folder 01
# 2023-09-11 16:19:01.053714: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
folder_path = 'Saved_Models'  # Replace this with the actual folder path
file_names = [AE_name +'_count.txt']

for name in file_names:
    file_path = os.path.join(main_dir, folder_path, name)
    with open(file_path, 'w') as f:
        f.write('0')
    print(f"Created {name} with content '0' in folder {folder_path}")
# Out:
# Created Fully_Convolutional_AE_STFT_count.txt with content '0' in folder Saved_Models

# %% [markdown]
# ### Preparation to use Keras-Tuner

# %% [markdown]
# This time the convolutional autoencoder builder have a code with more than 1 dimenision.

# %%
#FULLY CONVOLUTIONAL AUTOENCODER

# the real build function for general autoencoder (keras code)
def build_autoencoder(img_shape = INPUT_DIM,
                      code_channels = 3, # no more than 3 to be able to plot the code
                      activation = 'tanh',
                      n_layers = 2, #no more thank 4
                      n_units = 32,
                      kernel_size = (3,3),
                      strides = (2,2),
                      max_pooling = (2,2),
                      regularizer = 1e-4,
                      batch_norm = True,
                      drop_out = 0.0,
                      learning_rate = 1e-3,
                      loss = tf.keras.losses.MeanSquaredError(),
                      metrics = ['mse'],
                      AE_name = AE_name,
                      ):
    lr = learning_rate

    #check the number of layers
    if n_layers > 4:
        print('The number of layers is too high, it has been set to 4')
        n_layers = 4

    # encoder
    encoder = tf.keras.Sequential(name='Encoder')
    encoder.add(tf.keras.Input(img_shape))

    output_padding_list = []
    lambda_padding_list = []

    for i in range(n_layers):
        filters = n_units * (i+1) if i<n_layers-1 else code_channels
        encoder.add(layers.Conv2D(filters, kernel_size,strides = strides, activation = activation, padding='valid'))

        #save the conv2dtranspose padding for the decoder
        _,width,height,_ = encoder.layers[-1].input_shape
        pad = (width-(((width - kernel_size[0])//strides[0])*strides[0]+kernel_size[0]), height-(((height - kernel_size[1])//strides[1])*strides[1]+kernel_size[1]))
        output_padding_list.append( pad )

        encoder.add(layers.MaxPool2D(max_pooling, padding='valid'))

        #save the upsampling padding for the decoder
        _,width,height,_ = encoder.layers[-1].input_shape
        lambda_padding_list.append((width%max_pooling[0], height%max_pooling[1]))

        if batch_norm:
            encoder.add(layers.BatchNormalization())
        if drop_out > 0:
            encoder.add(layers.Dropout(drop_out))

    #check if the code size is reasonable small
    code_prod = np.prod(encoder.layers[-1].output_shape[1:])
    inp_prod = np.prod(INPUT_DIM)
    if code_prod > inp_prod/10:
        print('The input has dimension', np.prod(INPUT_DIM))
        print('The code size (flattened) is', np.prod(encoder.layers[-1].output_shape[1:]))
        print('We must decrease the number of channels at least to ', int(inp_prod/10*code_channels/code_prod))
        #show the input params
        print('The input params are:')
        print(f'code_channels = {code_channels}')
        print(f'n_layers = {n_layers}')
        print(f'n_units = {n_units}')
        print(f'kernel_size = {kernel_size}')
        print(f'strides = {strides}')
        print(f'max_pooling = {max_pooling}')



    # decoder
    decoder = tf.keras.Sequential(name='Decoder')
    decoder.add(tf.keras.Input(shape = encoder.layers[-1].output_shape[1:]))

    # transpose convolutions
    for i in range(n_layers):

        decoder.add(layers.UpSampling2D(size=max_pooling))
        pad = lambda_padding_list[-i-1]
        decoder.add(layers.Lambda(lambda x: tf.pad(x, [[0,0],[0,pad[0]],[0,pad[1]], [0,0]])))

        filters = n_units * (n_layers-i-1) if i<n_layers-1 else img_shape[-1]
        pad =  output_padding_list[-i-1]
        decoder.add(
            layers.Conv2DTranspose(filters , kernel_size, strides=strides, activation=activation, output_padding=pad)
        )

        if batch_norm:
            decoder.add(layers.BatchNormalization())
        if drop_out>0:
            decoder.add(layers.Dropout(drop_out))

    #resizing if needed
    if decoder.layers[-1].output_shape[1:] != INPUT_DIM:
        decoder.add(tf.keras.layers.Resizing(height = img_shape[0], width = img_shape[1], interpolation="bilinear", crop_to_aspect_ratio=False))


    # build the autoencoder with keras.Model
    inp = tf.keras.Input(shape = INPUT_DIM)
    code = encoder(inp)
    reconstruction = decoder(code)
    autoencoder = tf.keras.Model(inputs=inp, outputs=reconstruction, name = AE_name)

    # compile the autoencoder
    optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=lr) if sys.platform == 'darwin' or in_colab else tf.keras.optimizers.Adam(learning_rate = lr)
    autoencoder.compile(optimizer=optimizer,
                loss=loss,
                metrics=metrics)

    #print the number of trainable parameters
    print(f'Model built with { sum(tf.keras.backend.count_params(p) for p in autoencoder.trainable_variables)} trainable params')

    return autoencoder

# %%
verbose = 2
#test the build_autoencoder function
autoencoder = build_autoencoder(n_layers = 2, strides = (1,1), max_pooling = (2,2), code_channels = 1)
if verbose > 1 and autoencoder is not None:
    autoencoder.summary(line_length=100)
    autoencoder.layers[1].summary(line_length=100)
    autoencoder.layers[2].summary(line_length=100)
# Out:
# Model built with 1350 trainable params
# Model: "Fully_Convolutional_AE_STFT"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  input_53 (InputLayer)                       [(None, 64, 128, 1)]                    0
#
#  Encoder (Sequential)                        (None, 14, 30, 1)                       741
#
#  Decoder (Sequential)                        (None, 64, 128, 1)                      741
#
# ====================================================================================================
# Total params: 1,482
# Trainable params: 1,350
# Non-trainable params: 132
# ____________________________________________________________________________________________________
# Model: "Encoder"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  conv2d_33 (Conv2D)                          (None, 62, 126, 32)                     320
#
#  max_pooling2d_29 (MaxPooling2D)             (None, 31, 63, 32)                      0
#
#  batch_normalization_47 (BatchNormalization)  (None, 31, 63, 32)                     128
#
#  conv2d_34 (Conv2D)                          (None, 29, 61, 1)                       289
#
#  max_pooling2d_30 (MaxPooling2D)             (None, 14, 30, 1)                       0
#
#  batch_normalization_48 (BatchNormalization)  (None, 14, 30, 1)                      4
#
# ====================================================================================================
# Total params: 741
# Trainable params: 675
# Non-trainable params: 66
# ____________________________________________________________________________________________________
# Model: "Decoder"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  up_sampling2d_23 (UpSampling2D)             (None, 28, 60, 1)                       0
#
#  lambda_23 (Lambda)                          (None, 29, 61, 1)                       0
#
#  conv2d_transpose_23 (Conv2DTranspose)       (None, 31, 63, 32)                      320
#
#  batch_normalization_49 (BatchNormalization)  (None, 31, 63, 32)                     128
#
#  up_sampling2d_24 (UpSampling2D)             (None, 62, 126, 32)                     0
#
#  lambda_24 (Lambda)                          (None, 62, 126, 32)                     0
#
#  conv2d_transpose_24 (Conv2DTranspose)       (None, 64, 128, 1)                      289
#
#  batch_normalization_50 (BatchNormalization)  (None, 64, 128, 1)                     4
#
# ====================================================================================================
# Total params: 741
# Trainable params: 675
# Non-trainable params: 66
# ____________________________________________________________________________________________________
# 2023-08-28 02:08:22.137115: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.138313: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.139764: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.140842: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.141588: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.142240: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.142885: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.143553: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.144533: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.145652: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.146351: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.162094: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.162993: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.164298: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:22.165065: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.

# %%
# function to build the model using different hyperparameters (keras tuner code)
def build_model(hp):

    n_units = hp.Choice(name = 'n_units', values =  [4,8,16,32,64,128], default = 32)
    n_layers = hp.Int(name = 'n_layers', min_value = 1, max_value = 4, step=1, sampling='linear', default = 2)
    kernel_size = hp.Choice(name = 'kernel_size', values = [3,5,7], default = 3)
    strides = hp.Choice(name = 'strides', values = [2,3], default = 2)
    max_pooling = hp.Choice(name = 'max_pooling' , values = [2,3,4], default = 2)
    code_channels= hp.Int(name = 'code_channels', min_value = 1, max_value = 6, step = 1, sampling = 'linear', default = 3)
    activation = hp.Choice(name = 'activation', values = ['relu','elu','tanh'], default = 'tanh')
    drop_out = hp.Choice(name = 'drop_out', values = [0.0, 0.25, 0.5], default = 0.0)
    batch_norm = hp.Choice(name = 'batch_norm', values = [True, False], default = True)
    learning_rate= hp.Choice('learning_rate', values = [1e-4, 1e-3, 5*1e-3, 1e-2,5*1e-2,1e-1], default = 1e-3)


    model = build_autoencoder(code_channels = code_channels,
                              activation = activation,
                              n_layers = n_layers,
                              n_units = n_units,
                              kernel_size = (kernel_size,kernel_size),
                              strides = (strides,strides),
                              max_pooling = (max_pooling, max_pooling),
                              batch_norm = batch_norm,
                              drop_out = drop_out,
                              learning_rate= learning_rate)

    return model

# %%
#test the build_model function
build_model(kt.HyperParameters()).summary()
# Out:
# Model built with 2508 trainable params
# Model: "Fully_Convolutional_AE_STFT"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_56 (InputLayer)       [(None, 64, 128, 1)]      0
#
#  Encoder (Sequential)        (None, 3, 7, 3)           1327
#
#  Decoder (Sequential)        (None, 64, 128, 1)        1317
#
# =================================================================
# Total params: 2,644
# Trainable params: 2,508
# Non-trainable params: 136
# _________________________________________________________________
# 2023-08-28 02:08:24.274170: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:24.274887: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:24.275840: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:24.276484: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.

# %% [markdown]
# ### Implement the grid search hyperparamter-wise

# %%
# dictionary with the default values of the hyperparams to be update each time
default_values = {
    'n_layers': 2,
    'n_units': 3,
    'kernel_size': 3,
    'strides':2,
    'max_pooling':2,
    'code_channels':3,
    'activation':'tanh',
    'drop_out':0.0,
    'batch_norm':True,
    'learning_rate':1e-3
}

key_list = list(default_values.keys())

#define the general variables for our tuner
hpo_methods = ['RandomSearch', 'BayesianOptimization','Hyperband']
max_model_size = 10**7
max_trials = 100
dir_name = AE_name
verbose=0

if strong_pc:
    train_small = train
    val_small = val
else:       
    small_size_dataset = 40
    train_val_small = train.unbatch().take(small_size_dataset)
    train_small = train_val_small.skip(10).batch(25) 
    val_small = train_val_small.take(10).batch(25)

# define a list to collect all the best scores
best_score_dict ={
    'RandomSearch': [],
    'BayesianOptimization': [],
    'Hyperband': []
}

folder_to_delete = []

for hpo_method in hpo_methods:
    random.shuffle(key_list)
    for hyper_params in key_list:
        print(f'Searching for the best value for {hyper_params}')

        #define an hp set with all fix but one
        hp = kt.HyperParameters()

        for fixed_param in default_values.keys():
            if fixed_param != hyper_params:
                hp.Fixed(name = fixed_param, value = default_values[fixed_param])

        if verbose>1:
            display(hp.space)

        #create a tuner for the params not fixed
        tuner = build_tuner(build_model = build_model,
                            hpo_method = hpo_method,
                            max_model_size = max_model_size,
                            max_trials = max_trials,
                            dir_name = dir_name,
                            overwrite = True,
                            objective = kt.Objective('val_mse', direction='min'),
                            hp=hp,
                            not_fixed_param = hyper_params,
                            tune_new_entries=True
                            )

        if verbose>2:
            display(tuner.search_space_summary(extended = True))

        #fit the tuner
        epochs = 50
        patience = 10
        metrics = ['mse']
        callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_'+metrics[0],
                                                    verbose=verbose,
                                                    patience=patience)]

        tuner.search(train_small, validation_data = val_small,
                            callbacks=callbacks,
                            epochs=epochs,
                            verbose=int(verbose>0),
                    )

        #retrive the best value for the free hp
        best_value = tuner.get_best_hyperparameters()[0].values[hyper_params]

        #retrive the best score reached
        best_score = tuner.get_best_models(num_models=1)[0].evaluate(val, return_dict = True)['mse']

        print(f'The best value for {hyper_params} is {best_value}, the best score is {best_score}')
        best_score_dict[hpo_method].append(best_score)

        #update the default dict of values
        default_values[hyper_params] = best_value

        #save the updated dictionary
        file_path = os.path.join(main_dir, dir_name, hpo_method+'_best_params')
        with open(file_path, 'wb') as file:
            pickle.dump(default_values, file)

        #delete the folder just created by the run
        folder_to_delete.append(os.path.join(main_dir,dir_name, hpo_method+'_'+hyper_params))

    with open(file_path, 'rb') as file:
        best_params = pickle.load(file)

    display(best_params)

#save the best_score_dict
file_path = os.path.join(main_dir, dir_name, 'best_scores')
with open(file_path, 'wb') as file:
    pickle.dump(best_score_dict, file)

with open(file_path, 'rb') as file:
    best_scores = pickle.load(file)

display(best_scores)

for folder in folder_to_delete:
    shutil.rmtree(folder)
# Out:
# Searching for the best value for n_layers
# Using Random Search strategy for HPO
# Model built with 246 trainable params
# The input has dimension 8192
# The code size (flattened) is 1395
# We must decrease the number of channels at least to  1
# The input params are:
# code_channels = 3
# n_layers = 1
# n_units = 3
# kernel_size = (3, 3)
# strides = (2, 2)
# max_pooling = (2, 2)
# Model built with 66 trainable params
# Model built with 246 trainable params
# INFO:tensorflow:Oracle triggered exit
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 213, in _build_and_fit_model
#     model = self._try_build(hp)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 155, in _try_build
#     model = self._build_hypermodel(hp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/453418228.py", line 16, in build_model
#     model = build_autoencoder(code_channels = code_channels,
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/3731261895.py", line 43, in build_autoencoder
#     encoder.add(layers.MaxPool2D(max_pooling, padding='valid'))
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/framework/ops.py", line 1973, in _create_c_op
#     raise ValueError(e.message)
# ValueError: Exception encountered when calling layer "max_pooling2d_2" (type MaxPooling2D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling2d_2/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 1]](Placeholder)' with input shapes: [?,1,3,3].
#
# Call arguments received by layer "max_pooling2d_2" (type MaxPooling2D):
#   • inputs=tf.Tensor(shape=(None, 1, 3, 3), dtype=float32)
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 213, in _build_and_fit_model
#     model = self._try_build(hp)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 155, in _try_build
#     model = self._build_hypermodel(hp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/453418228.py", line 16, in build_model
#     model = build_autoencoder(code_channels = code_channels,
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/3731261895.py", line 43, in build_autoencoder
#     encoder.add(layers.MaxPool2D(max_pooling, padding='valid'))
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/framework/ops.py", line 1973, in _create_c_op
#     raise ValueError(e.message)
# ValueError: Exception encountered when calling layer "max_pooling2d_2" (type MaxPooling2D).
#
# Negative dimension size caused by subtracting 2 from 1 for '{{node max_pooling2d_2/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 1]](Placeholder)' with input shapes: [?,1,3,9].
#
# Call arguments received by layer "max_pooling2d_2" (type MaxPooling2D):
#   • inputs=tf.Tensor(shape=(None, 1, 3, 9), dtype=float32)
# Model built with 246 trainable params
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1456 - mse: 0.1456
# The best value for n_layers is 2, the best score is 0.14559097588062286
# Searching for the best value for batch_norm
# Using Random Search strategy for HPO
# Model built with 246 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 246 trainable params
# Model built with 226 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 226 trainable params
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0621 - mse: 0.0621
# The best value for batch_norm is 0, the best score is 0.062149617820978165
# Searching for the best value for kernel_size
# Using Random Search strategy for HPO
# Model built with 226 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 226 trainable params
# Model built with 610 trainable params
# 2023-08-27 19:00:11.403805: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: Incompatible shapes: [128,74,138,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]]
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py", line 58, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/BroadcastGradientArgs' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#       self._run_once()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#       handle._run()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/933145115.py", line 81, in <module>
#       tuner.search(train_small, validation_data = val_small,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 230, in search
#       self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#       self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#       results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#       obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#       results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#       return model.fit(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1054, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 585, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 643, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 519, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/mean_squared_error/BroadcastGradientArgs'
# Incompatible shapes: [128,74,138,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]] [Op:__inference_train_function_173138]
# Model built with 1186 trainable params
# INFO:tensorflow:Oracle triggered exit
# 2023-08-27 19:00:12.088836: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: Incompatible shapes: [128,64,128,1] vs. [128,72,136,1]
# 	 [[{{node mean_squared_error/SquaredDifference}}]]
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py", line 58, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'mean_squared_error/SquaredDifference' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#       self._run_once()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#       handle._run()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/933145115.py", line 81, in <module>
#       tuner.search(train_small, validation_data = val_small,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 230, in search
#       self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#       self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#       results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#       obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#       results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#       return model.fit(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1051, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1109, in compute_loss
#       return self.compiled_loss(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/losses.py", line 142, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/losses.py", line 268, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/losses.py", line 1470, in mean_squared_error
#       return backend.mean(tf.math.squared_difference(y_pred, y_true), axis=-1)
# Node: 'mean_squared_error/SquaredDifference'
# Incompatible shapes: [128,64,128,1] vs. [128,72,136,1]
# 	 [[{{node mean_squared_error/SquaredDifference}}]] [Op:__inference_train_function_175036]
# Model built with 226 trainable params
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0642 - mse: 0.0642
# The best value for kernel_size is 3, the best score is 0.0641651600599289
# Searching for the best value for max_pooling
# Using Random Search strategy for HPO
# Model built with 226 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 226 trainable params
# Model built with 226 trainable params
# INFO:tensorflow:Oracle triggered exit
# 2023-08-27 19:00:32.773899: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: Incompatible shapes: [128,64,130,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]]
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py", line 58, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/BroadcastGradientArgs' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#       self._run_once()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#       handle._run()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/933145115.py", line 81, in <module>
#       tuner.search(train_small, validation_data = val_small,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 230, in search
#       self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#       self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#       results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#       obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#       results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#       return model.fit(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1054, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 585, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 643, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 519, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/mean_squared_error/BroadcastGradientArgs'
# Incompatible shapes: [128,64,130,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]] [Op:__inference_train_function_192154]
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 213, in _build_and_fit_model
#     model = self._try_build(hp)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 155, in _try_build
#     model = self._build_hypermodel(hp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/453418228.py", line 16, in build_model
#     model = build_autoencoder(code_channels = code_channels,
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/3731261895.py", line 43, in build_autoencoder
#     encoder.add(layers.MaxPool2D(max_pooling, padding='valid'))
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/trackable/base.py", line 205, in _method_wrapper
#     result = method(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/framework/ops.py", line 1973, in _create_c_op
#     raise ValueError(e.message)
# ValueError: Exception encountered when calling layer "max_pooling2d_1" (type MaxPooling2D).
#
# Negative dimension size caused by subtracting 4 from 3 for '{{node max_pooling2d_1/MaxPool}} = MaxPool[T=DT_FLOAT, data_format="NHWC", explicit_paddings=[], ksize=[1, 4, 4, 1], padding="VALID", strides=[1, 4, 4, 1]](Placeholder)' with input shapes: [?,3,7,3].
#
# Call arguments received by layer "max_pooling2d_1" (type MaxPooling2D):
#   • inputs=tf.Tensor(shape=(None, 3, 7, 3), dtype=float32)
# Model built with 226 trainable params
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0608 - mse: 0.0608
# The best value for max_pooling is 2, the best score is 0.06075839325785637
# Searching for the best value for n_units
# Using Random Search strategy for HPO
# Model built with 2372 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 596 trainable params
# Model built with 1188 trainable params
# Model built with 2372 trainable params
# Model built with 300 trainable params
# Model built with 4740 trainable params
# Model built with 9476 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 9476 trainable params
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0480 - mse: 0.0480
# The best value for n_units is 128, the best score is 0.04797165095806122
# Searching for the best value for drop_out
# Using Random Search strategy for HPO
# Model built with 9476 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 9476 trainable params
# Model built with 9476 trainable params
# Model built with 9476 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 9476 trainable params
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0477 - mse: 0.0477
# The best value for drop_out is 0.0, the best score is 0.04774654284119606
# Searching for the best value for code_channels
# Using Random Search strategy for HPO
# Model built with 9476 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 7171 trainable params
# Model built with 9476 trainable params
# Model built with 11781 trainable params
# Model built with 4866 trainable params
# Model built with 14086 trainable params
# Model built with 16391 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 16391 trainable params
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0455 - mse: 0.0455
# The best value for code_channels is 6, the best score is 0.04549286141991615
# Searching for the best value for strides
# Using Random Search strategy for HPO
# Model built with 16391 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 16391 trainable params
# Model built with 16391 trainable params
# INFO:tensorflow:Oracle triggered exit
# 2023-08-27 19:25:47.500081: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: Incompatible shapes: [128,64,152,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]]
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py", line 58, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/BroadcastGradientArgs' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
# ...
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 643, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 519, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/mean_squared_error/BroadcastGradientArgs'
# Incompatible shapes: [128,66,130,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]] [Op:__inference_train_function_1031094]
# The input has dimension 8192
# The code size (flattened) is 1260
# We must decrease the number of channels at least to  1
# The input params are:
# code_channels = 3
# n_layers = 1
# n_units = 64
# kernel_size = (7, 7)
# strides = (2, 2)
# max_pooling = (2, 2)
# Model built with 306 trainable params
# INFO:tensorflow:Oracle triggered exit
# The input has dimension 8192
# The code size (flattened) is 1260
# We must decrease the number of channels at least to  1
# The input params are:
# code_channels = 3
# n_layers = 1
# n_units = 64
# kernel_size = (7, 7)
# strides = (2, 2)
# max_pooling = (2, 2)
# Model built with 306 trainable params
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0410 - mse: 0.0410
# The best value for kernel_size is 7, the best score is 0.04097888991236687
# Searching for the best value for max_pooling
# Using Hyperband strategy for HPO
# The input has dimension 8192
# The code size (flattened) is 1260
# We must decrease the number of channels at least to  1
# The input params are:
# code_channels = 3
# n_layers = 1
# n_units = 64
# kernel_size = (7, 7)
# strides = (2, 2)
# max_pooling = (2, 2)
# Model built with 306 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# The input has dimension 8192
# The code size (flattened) is 1260
# We must decrease the number of channels at least to  1
# The input params are:
# code_channels = 3
# n_layers = 1
# n_units = 64
# kernel_size = (7, 7)
# strides = (2, 2)
# max_pooling = (2, 2)
# Model built with 306 trainable params
# Model built with 306 trainable params
# 2023-08-27 20:26:49.982974: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: Incompatible shapes: [128,62,128,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]]
# Traceback (most recent call last):
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/tuners/hyperband.py", line 425, in run_trial
#     return super().run_trial(trial, *fit_args, **fit_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py", line 58, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/BroadcastGradientArgs' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#       self._run_once()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#       handle._run()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/bn/q7hx91b1081fm2grcj1g9npm0000gn/T/ipykernel_2821/933145115.py", line 81, in <module>
#       tuner.search(train_small, validation_data = val_small,
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 230, in search
#       self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 270, in _try_run_and_update_trial
#       self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/base_tuner.py", line 235, in _run_and_update_trial
#       results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/tuners/hyperband.py", line 425, in run_trial
#       return super().run_trial(trial, *fit_args, **fit_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 287, in run_trial
#       obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/tuner.py", line 214, in _build_and_fit_model
#       results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras_tuner/engine/hypermodel.py", line 144, in fit
#       return model.fit(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/engine/training.py", line 1054, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 585, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 643, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "/Users/leonardo/anaconda3/envs/DSEnv3/lib/python3.11/site-packages/keras/optimizers/legacy/optimizer_v2.py", line 519, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/mean_squared_error/BroadcastGradientArgs'
# Incompatible shapes: [128,62,128,1] vs. [128,64,128,1]
# 	 [[{{node gradient_tape/mean_squared_error/BroadcastGradientArgs}}]] [Op:__inference_train_function_1039657]
# Model built with 306 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 306 trainable params
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0410 - mse: 0.0410
# The best value for max_pooling is 4, the best score is 0.0409662090241909
# Searching for the best value for strides
# Using Hyperband strategy for HPO
# Model built with 306 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 306 trainable params
# Model built with 306 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 306 trainable params
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0410 - mse: 0.0410
# The best value for strides is 3, the best score is 0.04097721725702286
# Searching for the best value for activation
# Using Hyperband strategy for HPO
# Model built with 306 trainable params
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# Model built with 306 trainable params
# Model built with 306 trainable params
# Model built with 306 trainable params
# INFO:tensorflow:Oracle triggered exit
# Model built with 306 trainable params
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0408 - mse: 0.0408
# The best value for activation is elu, the best score is 0.0407908633351326
# {'n_layers': 1,
#  'n_units': 64,
#  'kernel_size': 7,
#  'strides': 3,
#  'max_pooling': 4,
#  'code_channels': 3,
#  'activation': 'elu',
#  'drop_out': 0.25,
#  'batch_norm': 1,
#  'learning_rate': 0.1}
# {'RandomSearch': [0.14559097588062286,
#   0.062149617820978165,
#   0.0641651600599289,
#   0.06075839325785637,
#   0.04797165095806122,
#   0.04774654284119606,
#   0.04549286141991615,
#   0.046734802424907684,
#   0.03631806746125221,
#   0.022332871332764626],
#  'BayesianOptimization': [0.021281970664858818,
#   0.013482089154422283,
#   0.010652109049260616,
#   0.006087672896683216,
#   0.014462283812463284,
#   0.006652801297605038,
#   0.006222887896001339,
#   0.006951751187443733,
#   0.007486728485673666,
#   0.0064633809961378574],
#  'Hyperband': [0.27196672558784485,
#   0.2859126031398773,
#   0.2730955183506012,
#   0.045933693647384644,
#   0.04587462544441223,
#   0.04105158522725105,
#   0.04097888991236687,
#   0.0409662090241909,
#   0.04097721725702286,
#   0.0407908633351326]}

# %%
# compare the best hp from the 3 grid search methods
hyperparamters = []
for hpo_method in  ['RandomSearch', 'BayesianOptimization','Hyperband']:
    file_path = os.path.join(main_dir, dir_name, hpo_method+'_best_params')
    with open(file_path, 'rb') as file:
        hyperparamters.append(pickle.load(file))
pd.DataFrame(hyperparamters, index = ['RandomSearch', 'BayesianOptimization','Hyperband'])
# Out:
#                       n_layers  n_units  kernel_size  strides  max_pooling  \
# RandomSearch                 2      128            3        2            2
# BayesianOptimization         1        8            7        2            2
# Hyperband                    1       64            7        3            4
#
#                       code_channels activation  drop_out  batch_norm  \
# RandomSearch                      6        elu      0.00           0
# BayesianOptimization              5       relu      0.00           1
# Hyperband                         3        elu      0.25           1
#
#                       learning_rate
# RandomSearch                  0.005
# BayesianOptimization          0.010
# Hyperband                     0.100

# %% [markdown]
# ### Train the model with best params on more data

# %%
insert_by_hand = True
dir_name = AE_name
if insert_by_hand:
    best_params = {
        'n_layers':2,
        'n_units':128,
        'kernel_size':(3,3),
        'strides':(2,2),
        'max_pooling':(2,2),5
        'code_channels':6,
        'activation':'elu',
        'drop_out':0,
        'batch_norm':True,
        'learning_rate':0.010,
    }
else:
    file_path = os.path.join(main_dir, dir_name, 'Hyperband'+'_best_params')
    with open(file_path, 'rb') as file:
        best_params = pickle.load(file)
        for key_double in ['kernel_size','strides','max_pooling']:
            best_params[key_double] = (best_params[key_double],best_params[key_double])


# build an autoencoder with the best params
autoencoder = build_autoencoder(**best_params)

#autoencoder = tuner.get_best_models(num_models=1)[0] #to create the model with some already wuite good weights
verbose=0
if verbose>0:
    autoencoder.summary()
    autoencoder.layers[1].summary()
    autoencoder.layers[2].summary()

epochs = 100
n_folders = 125 

US_training(AE_name = AE_name, 
            autoencoder = autoencoder, 
            epochs = epochs , 
            n_folders=n_folders, 
            preprocessing = preprocessing, 
            ndim=3,
            verbose = verbose)
# Out:
# 2023-08-28 02:08:28.450836: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.451789: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.453150: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.454059: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.471849: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.472575: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.473604: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.474214: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.570586: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.578146: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.587618: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.599698: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.601908: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.625756: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.626521: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.627132: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.628331: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.629511: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.631492: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.640791: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.643480: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:28.651278: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# Model built with 16917 trainable params
# Last folder trained: 0
# Creating the dataset from folder 01
# 2023-08-28 02:08:28.653715: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:29.724160: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.810954: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.811945: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.812543: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.826087: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.828228: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.833222: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.834996: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.836622: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:31.837257: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.043820: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.104023: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.104747: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.106195: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.106883: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.108996: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.118335: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.120604: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.486044: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.487782: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.492359: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.494071: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.534703: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.536502: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.895330: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.897063: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.901547: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.903119: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.939059: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:32.940696: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.300494: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.302594: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.307385: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.309072: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.350109: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.352730: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.728931: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.730768: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.736240: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.738014: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.773169: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:33.775223: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.154933: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.157979: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.166866: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.169532: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.205379: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.207050: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.565797: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.567719: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.572346: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.573977: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.612307: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.614252: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.973390: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.975102: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.979478: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:34.981096: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.022476: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.024122: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.383367: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.385066: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.389525: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.391082: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.426331: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.427983: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.785713: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.787449: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.791822: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.793357: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.830908: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:35.832585: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.194554: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.196473: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.201155: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.202906: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.237766: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.239443: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.592820: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.594544: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.599061: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.600806: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.634220: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.635336: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.637299: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.638260: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:36.641806: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# 2023-08-28 02:08:37.935514: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.936307: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.936902: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.937537: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.938158: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.939193: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.939815: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.940434: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.941225: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.943419: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.944185: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.944898: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.945667: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.950368: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.951117: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.953378: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.954194: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.954810: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.955448: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.956224: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.973043: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.975133: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.975617: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:37.976429: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# 2023-08-28 02:08:38.599038: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.716807: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.723306: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.729247: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.737986: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.739767: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.767461: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.771793: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.776595: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:38.778240: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# Creating the dataset from folder 02
# 2023-08-28 02:08:39.752810: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.385177: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.387003: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.391678: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.393348: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.598391: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.663052: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:40.665302: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.042255: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.044128: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.049045: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.051307: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.103495: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.105735: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.528315: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.532340: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.542578: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.546124: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.603595: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:41.608670: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.021817: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.024470: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.030908: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.033771: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.089370: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.093110: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.488634: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.492024: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.500279: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.503420: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.548383: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.550234: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.935272: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.938101: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.948178: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.950997: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.991802: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:42.993956: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.368936: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.372110: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.380759: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.383186: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.423007: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.425475: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.798099: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.800584: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.807249: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.809419: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.846440: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:43.848694: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.215542: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.217276: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.221958: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.224188: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.261111: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.262923: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.632910: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.634730: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.639635: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.641546: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.682171: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:44.683907: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.051103: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.052711: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.057082: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.058630: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.094452: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.096139: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.470331: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.472034: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.476521: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:45.478111: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# Creating the dataset from folder 03
# 2023-08-28 02:08:47.660122: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.666374: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.672453: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.680791: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.682513: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.719918: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.725068: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.730778: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:47.732719: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:49.212114: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:49.860614: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:49.863696: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:49.872061: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:49.875097: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.100809: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.157013: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.159040: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.524674: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.526376: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.530770: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.532313: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.566693: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.568420: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.938607: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.940290: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.944704: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.946273: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.979995: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:50.981655: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.352633: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.354336: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.358848: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.361403: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.408321: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.411038: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.771733: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.773413: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.777881: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.779429: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.813730: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:51.815407: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.176712: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.178365: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.182900: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.184438: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.217870: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.219524: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.592658: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.594330: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.598654: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.600170: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.637902: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:52.639541: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.010474: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.012214: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.016766: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.018367: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.055141: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.056823: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.421990: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.423662: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.428040: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.429580: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.466889: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.468562: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.841026: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.843417: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.847999: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.849696: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.885640: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:53.887434: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:54.259494: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:54.261487: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:54.267431: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:54.270010: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# Creating the dataset from folder 04
# 2023-08-28 02:08:56.407595: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.413928: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.421447: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.433244: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.435157: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.461915: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.465273: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.469865: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:56.471460: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:57.462059: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.140017: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.142254: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.148428: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.150566: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.356439: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.408510: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.410247: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.782761: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.784495: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.789015: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.790571: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.825349: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:58.827062: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.205853: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.208248: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.212681: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.214255: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.252528: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.254249: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.615479: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.617312: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.621926: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.623526: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.658407: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:08:59.660135: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.024855: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.027217: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.031592: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.033123: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.067171: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.068802: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.432817: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.434591: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.439072: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.440609: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.474841: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.476470: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.841907: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.843646: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.848045: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.849699: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.888092: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:00.890076: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.252786: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.254641: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.259399: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.263056: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.298503: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.300231: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.670604: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.672287: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.677023: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.678690: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.716279: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:01.717963: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.079910: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.081513: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.085943: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.087489: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.123181: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.125108: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.486520: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.489564: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.495714: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:02.497463: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# Creating the dataset from folder 05
# 2023-08-28 02:09:04.732590: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.741741: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.742836: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.744076: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.745873: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.746591: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.747377: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.748199: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.751587: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.752372: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.752990: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.753706: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.756968: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.761073: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.765116: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.768493: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.771511: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.774942: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.779059: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.782138: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.784815: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.785426: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.791999: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.793541: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.796437: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.798014: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:04.798626: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.441941: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.443521: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.444226: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.445918: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.446567: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.447325: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:08.448040: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.693051: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.698796: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.704327: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.709353: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.713833: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.718263: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.725284: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.732112: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.737859: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.738822: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.739563: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.740853: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.741885: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.742710: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.743534: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 02:09:22.744235: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# ...
# 2023-08-28 03:59:43.151734: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.152594: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.162701: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.164119: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.166412: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.167805: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.169813: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.171072: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:43.173611: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.830973: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.831814: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.841395: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.842817: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.845128: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.846619: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.848682: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.849942: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:47.852451: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:53.332077: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 03:59:54.275640: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# Creating the dataset from folder 124
# 2023-08-28 04:00:02.779884: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.784003: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.787783: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.790959: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.794705: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.798042: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.801742: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.804831: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.807886: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.811102: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.820909: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.822714: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.825776: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:02.827678: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.702275: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.707258: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.710987: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.713804: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.716558: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.719382: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.723746: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.728773: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.733420: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.739658: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.740741: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.756951: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.758448: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.760783: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.762224: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.764248: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.765525: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:22.768059: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:32.760314: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 643 of 1500
# 2023-08-28 04:00:41.888942: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 2023-08-28 04:00:41.981101: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:41.982248: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:41.996807: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:41.998693: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:42.001705: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:42.003561: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:42.006162: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:42.007800: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:42.011055: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.698176: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.699297: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.714069: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.715858: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.718571: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.720314: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.722732: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.724256: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:46.727467: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:52.488839: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:00:53.495477: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# Creating the dataset from folder 125
# 2023-08-28 04:01:06.694758: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.699812: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.703738: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.707521: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.710921: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.713968: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.717195: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.720113: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.723948: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.727318: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.735414: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.736977: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.739623: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:06.741271: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.806230: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.809380: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.812511: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.815064: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.817790: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.820436: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.824542: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.828376: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.832368: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.839659: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.840665: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.854291: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.855815: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.858185: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.859618: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.861642: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.862924: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:26.865483: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:36.859589: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 581 of 1500
# 2023-08-28 04:01:46.203316: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# 2023-08-28 04:01:46.312571: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.313484: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.323847: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.325286: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.327696: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.329179: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.331267: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.332561: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:46.335174: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.315705: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.317111: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.331979: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.333765: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.336195: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.337690: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.339783: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.341112: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:51.343776: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:57.180055: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:01:58.190209: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# INFO:tensorflow:Assets written to: /home/leonardo/Desktop/HDA/Human_Data_Analytics_Project_2023/Saved_Models/Fully_Convolutional_AE_STFT/assets
# This model has a size of 0.25861358642578125 MB
# This model has a size of 0.25861358642578125 MB

# %%
create_US_dataset(folder_number=5, preprocessing = preprocessing, main_dir = main_dir, ndim=3, verbose=0)
# Out:
# Creating the dataset from folder 05
# 2023-08-28 04:02:04.073733: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:02:04.113531: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:02:04.135569: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:02:04.158774: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# 2023-08-28 04:02:04.169440: I tensorflow/core/common_runtime/gpu_fusion_pass.cc:507] ROCm Fusion is enabled.
# (<_LoadDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None))>,
#  <_LoadDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None))>,
#  <_LoadDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None))>,
#  TensorShape([64, 128, 1]))

# %% [markdown]
# ### Show the reconstruction capabilities of the model

# %%
#load the saved model
model_loaded = tf.keras.models.load_model(os.path.join(main_dir,'Saved_Models',AE_name))
model_loaded.summary()

#plot the original and reconstructed
plot_original_reconstructed(model = model_loaded, n_figures = 5, test=test)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RestoredOptimizer` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RestoredOptimizer`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "Fully_Convolutional_AE_STFT"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_59 (InputLayer)       [(None, 64, 128, 1)]      0
#
#  Encoder (Sequential)        (None, 3, 7, 6)           8734
#
#  Decoder (Sequential)        (None, 64, 128, 1)        8709
#
# =================================================================
# Total params: 17,443
# Trainable params: 16,917
# Non-trainable params: 526
# _________________________________________________________________
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step

# %% [markdown]
# Since there's less variability in the audio from unlabelled dataset we evaluate the autoencoder reconstruction on the labelled dataset.

# %%
train, val, test, label_names = create_dataset( ESC10_path,
                                                verbose = 0,
                                                batch_size = 30,
                                                validation_split = 0.25, # this is the splitting of train vs validation + test
                                                normalize = True, # normalization preprocessing (default is true)
                                                preprocessing = preprocessing,   # "STFT" or "MFCC"
                                                show_example_batch = False,
                                                ndim=3,
                                                resize = True,
                                                new_width = 64,
                                                new_height= 128)
model_loaded = tf.keras.models.load_model(os.path.join(main_dir,'Saved_Models',AE_name))
model_loaded.summary()
# show n original and reconstructed images
plot_original_reconstructed(model = model_loaded, n_figures = 5, test=test)
# Out:
# Found 400 files belonging to 10 classes.
# Using 300 files for training.
# Using 100 files for validation.
# 2023-09-11 16:19:05.400034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:05.400253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RestoredOptimizer` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RestoredOptimizer`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "Fully_Convolutional_AE_STFT"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_59 (InputLayer)       [(None, 64, 128, 1)]      0
#
#  Encoder (Sequential)        (None, 3, 7, 6)           8734
#
#  Decoder (Sequential)        (None, 64, 128, 1)        8709
#
# =================================================================
# Total params: 17,443
# Trainable params: 16,917
# Non-trainable params: 526
# _________________________________________________________________
# 2023-09-11 16:19:07.909827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [100]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:07.910137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [100]
# 	 [[{{node Placeholder/_4}}]]
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step

# %%
from Visualization.model_plot import plot_original_reconstructed_latent
plot_original_reconstructed_latent(model = model_loaded, n_figures = 5, test=test)
# Out:
# (1, 3, 7, 6)
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2023-09-11 16:19:08.693340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [100]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:08.693677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [100]
# 	 [[{{node Placeholder/_4}}]]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step

# %% [markdown]
# ### Plot the latent space

# %%
AE_name = 'Fully_Convolutional_AE_STFT'

# %%
#load the saved model
model_loaded = tf.keras.models.load_model(os.path.join(main_dir,'Saved_Models',AE_name))
encoder = model_loaded.layers[1]
encoder.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RestoredOptimizer` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RestoredOptimizer`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 31, 63, 128)       1280
#
#  max_pooling2d_33 (MaxPoolin  (None, 15, 31, 128)      0
#  g2D)
#
#  batch_normalization_55 (Bat  (None, 15, 31, 128)      512
#  chNormalization)
#
#  conv2d_38 (Conv2D)          (None, 7, 15, 6)          6918
#
#  max_pooling2d_34 (MaxPoolin  (None, 3, 7, 6)          0
#  g2D)
#
#  batch_normalization_56 (Bat  (None, 3, 7, 6)          24
#  chNormalization)
#
# =================================================================
# Total params: 8,734
# Trainable params: 8,466
# Non-trainable params: 268
# _________________________________________________________________

# %%
df_ESC10, df_ESC50 = load_metadata(main_dir, ESC_US = False, statistics=False)
# Out:
#             filename  fold  target        category  esc10  src_file take  \
# 0   1-100032-A-0.wav     1       0             dog   True    100032    A
# 1  1-100038-A-14.wav     1      14  chirping_birds  False    100038    A
# 2  1-100210-A-36.wav     1      36  vacuum_cleaner  False    100210    A
# 3  1-100210-B-36.wav     1      36  vacuum_cleaner  False    100210    B
# 4  1-101296-A-19.wav     1      19    thunderstorm  False    101296    A
#
#                                            full_path
# 0  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 1  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 2  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 3  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 4  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# Classes in the full dataset  are perfectly balanced
#  Counter({'dog': 40, 'chirping_birds': 40, 'vacuum_cleaner': 40, 'thunderstorm': 40, 'door_wood_knock': 40, 'can_opening': 40, 'crow': 40, 'clapping': 40, 'fireworks': 40, 'chainsaw': 40, 'airplane': 40, 'mouse_click': 40, 'pouring_water': 40, 'train': 40, 'sheep': 40, 'water_drops': 40, 'church_bells': 40, 'clock_alarm': 40, 'keyboard_typing': 40, 'wind': 40, 'footsteps': 40, 'frog': 40, 'cow': 40, 'brushing_teeth': 40, 'car_horn': 40, 'crackling_fire': 40, 'helicopter': 40, 'drinking_sipping': 40, 'rain': 40, 'insects': 40, 'laughing': 40, 'hen': 40, 'engine': 40, 'breathing': 40, 'crying_baby': 40, 'hand_saw': 40, 'coughing': 40, 'glass_breaking': 40, 'snoring': 40, 'toilet_flush': 40, 'pig': 40, 'washing_machine': 40, 'clock_tick': 40, 'sneezing': 40, 'rooster': 40, 'sea_waves': 40, 'siren': 40, 'cat': 40, 'door_wood_creaks': 40, 'crickets': 40})
#              filename  fold  target        category  src_file take  \
# 0    1-100032-A-0.wav     1       0             dog    100032    A
# 14   1-110389-A-0.wav     1       0             dog    110389    A
# 24  1-116765-A-41.wav     1      41        chainsaw    116765    A
# 54   1-17150-A-12.wav     1      12  crackling_fire     17150    A
# 55  1-172649-A-40.wav     1      40      helicopter    172649    A
#
#                                             full_path
# 0   /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 14  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 24  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 54  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# 55  /Users/leonardo/Desktop/HDA/Human_Data_Analyti...
# Classes in ESC10
#  ['rain', 'crackling_fire', 'helicopter', 'rooster', 'sneezing', 'chainsaw', 'sea_waves', 'dog', 'crying_baby', 'clock_tick']

# %%
plot_clip_overview_latent_space(encoder, train, label_names, n_figures = 5, column=5) # if give test there are not enough examples
# Out:
# 2023-09-11 16:19:10.266360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:10.266706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
# 2023-09-11 16:19:11.857006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:11.857354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
# 2023-09-11 16:19:11.993910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:11.994259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:12.139905: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:12.140236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:12.276361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
# 2023-09-11 16:19:12.276696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:12.422533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:12.422866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [300]
# 	 [[{{node Placeholder/_4}}]]
# 2023-09-11 16:19:12.562190: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:12.562530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
# 2023-09-11 16:19:12.703605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:12.703947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:12.845866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
# 2023-09-11 16:19:12.846207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
# 2023-09-11 16:19:12.984226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [300]
# 	 [[{{node Placeholder/_0}}]]
# 2023-09-11 16:19:12.984562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float
# 	 [[{{node Placeholder/_22}}]]
